-- %% [markdown]
-- # [Prueba_germannavarro]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Prueba_germannavarro]    Script Date: 19/10/2023 7:34:02 p. m. ******/
CREATE DATABASE [Prueba_germannavarro]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Prueba_germannavarro', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Prueba_germannavarro.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Prueba_germannavarro_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Prueba_germannavarro_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Prueba_germannavarro] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Prueba_germannavarro].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Prueba_germannavarro] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET ARITHABORT OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Prueba_germannavarro] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Prueba_germannavarro] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Prueba_germannavarro] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Prueba_germannavarro] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Prueba_germannavarro] SET  MULTI_USER 
GO
ALTER DATABASE [Prueba_germannavarro] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Prueba_germannavarro] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Prueba_germannavarro] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Prueba_germannavarro] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Prueba_germannavarro] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Prueba_germannavarro] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Prueba_germannavarro] SET QUERY_STORE = ON
GO
ALTER DATABASE [Prueba_germannavarro] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[movimientos]

-- %%
USE [Prueba_germannavarro]
GO

-- %%
/****** Object:  Table [dbo].[movimientos]    Script Date: 19/10/2023 7:34:02 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[movimientos](
	[fecha] [date] NOT NULL,
	[hora] [time](7) NOT NULL,
	[tipo_movimiento] [varchar](50) NOT NULL,
	[dato_anterior] [varchar](50) NOT NULL,
	[dato_nuevo] [varchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[paciente]

-- %%
/****** Object:  Table [dbo].[paciente]    Script Date: 19/10/2023 7:34:02 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[paciente](
	[Id] [int] NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[nombre2] [varchar](50) NOT NULL,
	[apellido] [varchar](50) NOT NULL,
	[direccion] [varchar](100) NOT NULL,
	[ciudad] [varchar](100) NOT NULL,
	[telefono] [varchar](50) NOT NULL,
	[correo_electronico] [varchar](100) NOT NULL,
	[genero] [char](1) NOT NULL,
	[fecha_nacimiento] [varchar](5) NOT NULL,
 CONSTRAINT [PK_paciente] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [TR_paciente_Delete]

-- %%
/****** Object:  Trigger [dbo].[TR_paciente_Delete]    Script Date: 19/10/2023 7:34:02 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TRIGGER [dbo].[TR_paciente_Delete]
ON [dbo].[paciente]
AFTER DELETE
AS
BEGIN
    INSERT INTO movimientos(tipo_movimiento, fecha, hora, dato_anterior)
    SELECT 'Eliminación', GETDATE(), GETDATE(), d.nombre
    FROM deleted d;
END;
GO
ALTER TABLE [dbo].[paciente] ENABLE TRIGGER [TR_paciente_Delete]
GO

-- %% [markdown]
-- # [TR_paciente_Insert]

-- %%
/****** Object:  Trigger [dbo].[TR_paciente_Insert]    Script Date: 19/10/2023 7:34:02 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TRIGGER [dbo].[TR_paciente_Insert]
ON [dbo].[paciente]
AFTER INSERT
AS
BEGIN
	INSERT INTO movimientos (tipo_movimiento,fecha,hora)
	SELECT 'insercion',GETDATE(),GETDATE()
	FROM inserted;
END;
GO
ALTER TABLE [dbo].[paciente] ENABLE TRIGGER [TR_paciente_Insert]
GO

-- %% [markdown]
-- # [TR_paciente_Update]

-- %%
/****** Object:  Trigger [dbo].[TR_paciente_Update]    Script Date: 19/10/2023 7:34:02 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TRIGGER [dbo].[TR_paciente_Update]
ON [dbo].[paciente]
AFTER UPDATE
AS
BEGIN
    INSERT INTO movimientos (tipo_movimiento, hora, fecha, dato_nuevo, dato_anterior)
    SELECT 'actualizacion', GETDATE(), GETDATE(),d.nombre, i.nombre
    FROM deleted d
    INNER JOIN inserted i ON d.Id = i.Id;
END;
GO
ALTER TABLE [dbo].[paciente] ENABLE TRIGGER [TR_paciente_Update]
GO

-- %% [markdown]
-- # [Prueba_germannavarro]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Prueba_germannavarro] SET  READ_WRITE 
GO
